# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))


from data_loader import load_documents_from_folder, build_corpus

folder_path = "../data/raw"

documents = load_documents_from_folder(folder_path)
corpus = build_corpus(documents)

print("Number of documents:", len(documents))
print("Total corpus length:", len(corpus))
# Out:
# Number of documents: 10
# Total corpus length: 412341

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from preprocessing import preprocess_corpus
#       3 processed_docs = preprocess_corpus(documents)
#       5 print("Number of processed documents:", len(processed_docs))
#
# ModuleNotFoundError: No module named 'preprocessing'
